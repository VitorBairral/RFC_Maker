# %%
import RFC_Maker as maker

# %%
cavidade = maker.Cavity()

cavidade.settings["cell_length"] = 30
cavidade.settings["cell_radius"] = 22.96
cavidade.settings["bp_length"] = 3.0
cavidade.settings["bp_radius"] = 1.0
cavidade.settings["E0"] = 2617993.8779914943

cavidade.generate()
# Out:
# RF cavity
#
# $reg kprob = 1,
# kmethod = 1,
# dx = .2,
# freq = 1000.0,
# beta = 1.0,
# ezero = 2617993.8779914943,
# rmass = 0.551,
# nbsup = 1,
# nbslo = 0,
# nbsrt = 1,
# nbslf = 1,
# xdri = 15.0,
# ydri = 11.48,
# clength = 30 $
